# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Winston_Salem_Bus_Riders.xlsx - Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Columns: 110 entries, recordid to hrs_wk_home_to_from_work
# dtypes: float64(13), int64(92), object(5)
# memory usage: 184.9+ KB

# %%
df_corr = df[['wage_primary_job','hrs_wk_prim_job','hrs_wk_all_jobs','avg_wage_other_jobs','mins_last_stop_to_work','mins_bus_home_to_work', 'mins_bus_work_to_home','wage_old_vs_new_job', 'wage_new_vs_old_job','prmote_pay_wage', 'age','zip_code','bus_time_get_to_doctor', 'vehicle_time_to_doctor','years_used_pub_tran_corr', 'annual_inc']]

# %%
df_corr.describe()
# Out:
#        wage_primary_job  hrs_wk_prim_job  hrs_wk_all_jobs  \
# count         215.00000       215.000000       215.000000
# mean           10.14186        32.595349        35.776744
# std             3.58666        12.385512        16.597388
# min             4.00000         2.000000         2.000000
# 25%             8.00000        25.000000        25.000000
# 50%            10.00000        35.000000        36.000000
# 75%            11.00000        40.000000        40.000000
# max            37.50000        80.000000        90.000000
#
#        avg_wage_other_jobs  mins_last_stop_to_work  mins_bus_home_to_work  \
# count            34.000000              215.000000             215.000000
# mean             18.740000               15.139535              66.795349
# std              49.862931               17.157573              34.539494
# min               7.000000                0.000000              10.000000
# ...

# %%
df_corr.corr()
# Out:
#                           wage_primary_job  hrs_wk_prim_job  hrs_wk_all_jobs  \
# wage_primary_job                  1.000000         0.231195         0.320883
# hrs_wk_prim_job                   0.231195         1.000000         0.819310
# hrs_wk_all_jobs                   0.320883         0.819310         1.000000
# avg_wage_other_jobs              -0.050298        -0.155496        -0.144762
# mins_last_stop_to_work            0.029709        -0.053278        -0.040651
# mins_bus_home_to_work             0.089275         0.112458         0.145071
# mins_bus_work_to_home             0.071834         0.130704         0.154812
# wage_old_vs_new_job               0.229607        -0.034357         0.045573
# wage_new_vs_old_job               0.470688         0.124822         0.242431
# prmote_pay_wage                   0.205901        -0.134766        -0.066234
# age                               0.033956        -0.205511        -0.222388
# ...

# %%
sns.heatmap(df_corr.corr())
